# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulhay04/Abdulhay04/blob/main/My_first_graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

plt.figure(figsize = (5, 3), dpi = 100)

# plt.plot(x, y, label = '2x', color = "red", linewidth = 2, marker = '.', linestyle = '--', markersize = 10, markeredgecolor = 'blue')
plt.plot(x, y, 'b^--', label = '2x')

x2 = np.arange(0.4, 4.5, 0.5)
plt.plot(x2[:6], x2[:6]**2, 'r', label = 'x^2')
plt.plot(x2[4:], x2[4:]**2, 'r--')


plt.title('Our first Graph!', fontdict={'fontname': 'Comic Sans MS'})

plt.xlabel('X Axis')
plt.ylabel('Y Axis')

plt.xticks([0, 1, 2, 3, 4])
# plt.yticks([0, 2, 4, 6, 8, 10])

plt.legend()

plt.savefig('mygraph.png', dpi = 300)

plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['Comic Sans MS'] not found. Falling back to DejaVu Sans.

# %%
labels = ['A', 'B', 'C']
values = [1, 4, 2]

bars = plt.bar(labels, values)

patterns = ['/', 'o', '*']
for bar in bars:
  bar.set_hatch(patterns.pop(0))

# bars[0].set_hatch('/')
# bars[0].set_hatch('o')
# bars[0].set_hatch('*')

plt.figure(figsize = (6, 4))

plt.show()

# %%
# data to display on plots
x = [3, 1, 3]
y = [3, 2, 1]
plt.plot(x, y)
plt.plot(y, x)
 
# Adding the legends
plt.legend(["blue", "orange"])
plt.show()
